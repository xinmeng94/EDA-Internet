# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import plotly
import plotly.express as px

# %%
# %matplotlib inline

# %%
df_precio_internet = pd.read_csv('Datos/cities_internet_prices.19-10-2021.csv')
df_precio_internet
# Out:
#                  City                 "Region"                    "Country"  \
# 0       New York City               "New York"   "United States of America"
# 1    Washington, D.C.   "District of Columbia"   "United States of America"
# 2       San Francisco             "California"   "United States of America"
# 3              Berlin                       ""                    "Germany"
# 4         Los Angeles             "California"   "United States of America"
# ..                ...                      ...                          ...
# 514            Kaunas                       ""                  "Lithuania"
# 515           Antwerp         "Flemish Region"                    "Belgium"
# 516          Zaragoza                 "Aragon"                      "Spain"
# 517         Arlington               "Virginia"   "United States of America"
# 518            Jubail       "Eastern Province"               "Saudi Arabia"
#
#       "InternetPrice"
# 0           66.441395
# 1           60.590455
# 2           68.988824
# 3           35.827084
# 4           66.690222
# ..                ...
# 514         11.211636
# 515         54.136225
# 516         31.842382
# 517         58.875000
# 518         52.158321
#
# [519 rows x 4 columns]

# %%
df_precio_internet.columns = ['City','Region','Country','InternetPrice']
df_precio_internet['Region']=df_precio_internet['Region'].apply(lambda x : x.replace('"',''))
df_precio_internet['Country']=df_precio_internet['Country'].apply(lambda x : x.replace('"',''))
df_precio_internet["InternetPrice"] = df_precio_internet["InternetPrice"].round(2)

# %%
df_precio_internet
# Out:
#                  City                 Region                    Country  \
# 0       New York City               New York   United States of America
# 1    Washington, D.C.   District of Columbia   United States of America
# 2       San Francisco             California   United States of America
# 3              Berlin                                           Germany
# 4         Los Angeles             California   United States of America
# ..                ...                    ...                        ...
# 514            Kaunas                                         Lithuania
# 515           Antwerp         Flemish Region                    Belgium
# 516          Zaragoza                 Aragon                      Spain
# 517         Arlington               Virginia   United States of America
# 518            Jubail       Eastern Province               Saudi Arabia
#
#      InternetPrice
# 0            66.44
# 1            60.59
# 2            68.99
# 3            35.83
# 4            66.69
# ..             ...
# 514          11.21
# 515          54.14
# 516          31.84
# 517          58.88
# 518          52.16
#
# [519 rows x 4 columns]

# %%
df_precio_por_pais = df_precio_internet.groupby("Country")[["InternetPrice"]].mean()
df_precio_por_pais = df_precio_por_pais.reset_index()
df_precio_por_pais['Country']=df_precio_por_pais.iloc[:,0].apply(lambda x : x.replace(' ',''))

# %%
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('Russia', 'Russian Federation')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('UnitedArabEmirates', 'United Arab Emirates')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('NorthMacedonia', 'North Macedonia')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('TrinidadandTobago', 'Trinidad and Tobago')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('DominicanRepublic', 'Dominican Republic')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('Turkey', 'Turkiye')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('Slovakia', 'Slovak Republic')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('SaudiArabia', 'Saudi Arabia')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('BosniaandHerzegovina', 'Bosnia and Herzegovina')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('SouthKorea', 'Korea, Rep.')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('Brunei', 'Brunei Darussalam')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('CzechRepublic', 'Czech Republic')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('TheBahamas', 'Bahamas, The')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('Kyrgyzstan', 'Kyrgyz Republic')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('Egypt', 'Egypt, Arab Rep.')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('UnitedStatesofAmerica', 'United States')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('ElSalvador', 'El Salvador')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('UnitedKingdom', 'United Kingdom')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace('SriLanka', 'Sri Lanka')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace("People'sRepublicofChina", 'China')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace("CostaRica", 'Costa Rica')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace("NewZealand", 'New Zealand')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace("Iran", 'Iran, Islamic Rep.')
df_precio_por_pais["Country"] = df_precio_por_pais["Country"].replace("SouthAfrica", 'South Africa')

# %%
df_poblacion_uso_internet = pd.read_csv('Datos/dato_población_internet.csv')
df_poblacion_uso_internet.head()
# Out:
#                                         Series Name     Series Code  \
# 0  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 1  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 2  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 3  Individuals using the Internet (% of population)  IT.NET.USER.ZS
# 4  Individuals using the Internet (% of population)  IT.NET.USER.ZS
#
#      Country Name Country Code 1990 [YR1990] 2018 [YR2018] 2019 [YR2019]  \
# 0     Afghanistan          AFG             0          16.8          17.6
# 1         Albania          ALB             0          65.4   68.55039112
# 2         Algeria          DZA             0   49.03846808          57.9
# 3  American Samoa          ASM             0            ..            ..
# 4         Andorra          AND             0            ..            ..
#
#   2020 [YR2020]
# 0          18.4
# 1         72.24
# 2          62.9
# 3            ..
# 4            ..

# %%
df_uso_2020 = df_poblacion_uso_internet.drop(df_poblacion_uso_internet.loc[:,"Series Name":"Series Code"],axis=1)
df_uso_2020 = df_uso_2020.drop(df_poblacion_uso_internet.loc[:,"1990 [YR1990]":"2018 [YR2018]"],axis=1)
df_uso_2020 = df_uso_2020.rename(columns={"Country Name":"Country"})
df_uso_2020 = df_uso_2020.drop(range(217,271))

# %%
df_uso_2020["2020 [YR2020]"] = df_uso_2020["2020 [YR2020]"].replace('..', '').replace('', np.nan).astype(float)

# %%
df_uso_2020 = df_uso_2020.fillna(method="ffill",axis=1)

# %%
df_uso_2020 = df_uso_2020.drop("2019 [YR2019]",axis=1)

# %%
df_uso_2020["2020 [YR2020]"]=pd.to_numeric(df_uso_2020["2020 [YR2020]"],'coerce')
df_uso_2020=df_uso_2020.dropna()

# %%
df_uso_2020
# Out:
#                 Country Country Code  2020 [YR2020]
# 0           Afghanistan          AFG          18.40
# 1               Albania          ALB          72.24
# 2               Algeria          DZA          62.90
# 5                Angola          AGO          36.00
# 7             Argentina          ARG          85.50
# ..                  ...          ...            ...
# 208          Uzbekistan          UZB          71.10
# 211             Vietnam          VNM          70.30
# 213  West Bank and Gaza          PSE          74.60
# 215              Zambia          ZMB          19.80
# 216            Zimbabwe          ZWE          29.30
#
# [157 rows x 3 columns]

# %%
df_uso_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 157 entries, 0 to 216
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        157 non-null    object
#  1   Country Code   157 non-null    object
#  2   2020 [YR2020]  157 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 4.9+ KB

# %%
df_resultado = df_precio_por_pais.merge(df_uso_2020,on="Country")
df_resultado
# Out:
#            Country  InternetPrice Country Code  2020 [YR2020]
# 0          Albania      21.160000          ALB          72.24
# 1          Algeria      45.180000          DZA          62.90
# 2        Argentina      29.414000          ARG          85.50
# 3          Armenia      17.690000          ARM          76.51
# 4        Australia      51.661250          AUS          89.60
# ..             ...            ...          ...            ...
# 99   United States      66.410901          USA          90.90
# 100        Uruguay      32.340000          URY          86.10
# 101     Uzbekistan      33.560000          UZB          71.10
# 102        Vietnam      10.575000          VNM          70.30
# 103       Zimbabwe     104.830000          ZWE          29.30
#
# [104 rows x 4 columns]

# %%
df_resultado["2020 [YR2020]"].astype(float)
# Out:
# 0      72.24
# 1      62.90
# 2      85.50
# 3      76.51
# 4      89.60
#        ...
# 99     90.90
# 100    86.10
# 101    71.10
# 102    70.30
# 103    29.30
# Name: 2020 [YR2020], Length: 104, dtype: float64

# %%
df_resultado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104 entries, 0 to 103
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        104 non-null    object
#  1   InternetPrice  104 non-null    float64
#  2   Country Code   104 non-null    object
#  3   2020 [YR2020]  104 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 4.1+ KB

# %%
df_resultado = df_resultado.rename(columns={"2020 [YR2020]":"population internet use 2020"})

# %%
df_pib = pd.read_csv('Datos/gdp.csv')
df_pib = df_pib.drop(df_pib.loc[:,"Code":"2019"],axis=1)
df_pib = df_pib.drop("Unnamed: 65",axis=1)
df_pib = df_pib.rename(columns={"Country Name":"Country","2020":"PIB 2020 (cien millones)"})

# %%
df_pib["PIB 2020 (cien millones)"] = df_pib["PIB 2020 (cien millones)"].apply(lambda x : x/(10**11))

# %%
df_resultado = df_resultado.merge(df_pib,on="Country")
df_resultado.head()
# Out:
#      Country  InternetPrice Country Code  population internet use 2020  \
# 0    Albania       21.16000          ALB                         72.24
# 1    Algeria       45.18000          DZA                         62.90
# 2  Argentina       29.41400          ARG                         85.50
# 3    Armenia       17.69000          ARM                         76.51
# 4  Australia       51.66125          AUS                         89.60
#
#    PIB 2020 (cien millones)
# 0                  0.148876
# 1                  1.450092
# 2                  3.892881
# 3                  0.126412
# 4                 13.278362

# %%
df_pib_percapita = pd.read_csv('Datos/gdp_per_capita.csv')
df_pib_percapita = df_pib_percapita.drop(df_pib_percapita.loc[:,"Code":"2019"],axis=1).drop("Unnamed: 65",axis=1)
df_pib_percapita = df_pib_percapita.rename(columns={"Country Name":"Country","2020":"PIB_per_capita 2020"})

# %%
df_resultado = df_resultado.merge(df_pib_percapita,on="Country")
df_resultado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 103 entries, 0 to 102
# Data columns (total 6 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       103 non-null    object
#  1   InternetPrice                 103 non-null    float64
#  2   Country Code                  103 non-null    object
#  3   population internet use 2020  103 non-null    float64
#  4   PIB 2020 (cien millones)      103 non-null    float64
#  5   PIB_per_capita 2020           103 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 5.6+ KB

# %%
df_industria = pd.read_csv("Datos/Industry (including construction), value added (% of GDP).csv")
df_industria
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                         Indicator Name  Indicator Code  \
# 0    Industry (including construction), value added...  NV.IND.TOTL.ZS
# 1    Industry (including construction), value added...  NV.IND.TOTL.ZS
# 2    Industry (including construction), value added...  NV.IND.TOTL.ZS
# 3    Industry (including construction), value added...  NV.IND.TOTL.ZS
# 4    Industry (including construction), value added...  NV.IND.TOTL.ZS
# ..                                                 ...             ...
# 261  Industry (including construction), value added...  NV.IND.TOTL.ZS
# 262  Industry (including construction), value added...  NV.IND.TOTL.ZS
# 263  Industry (including construction), value added...  NV.IND.TOTL.ZS
# 264  Industry (including construction), value added...  NV.IND.TOTL.ZS
# 265  Industry (including construction), value added...  NV.IND.TOTL.ZS
#
#           1960       1961       1962       1963       1964       1965  ...  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN  ...
# 1          NaN        NaN        NaN        NaN        NaN        NaN  ...
# 2          NaN        NaN        NaN        NaN        NaN        NaN  ...
# 3          NaN        NaN        NaN        NaN        NaN        NaN  ...
# 4          NaN        NaN        NaN        NaN        NaN        NaN  ...
# ..         ...        ...        ...        ...        ...        ...  ...
# 261        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 262        NaN        NaN        NaN        NaN        NaN        NaN  ...
# 263  32.469195  32.716237  32.853067  33.277441  34.192037  35.168720  ...
# 264  62.151873  59.417316  58.037923  57.742000  58.134786  53.812665  ...
# 265        NaN        NaN        NaN        NaN        NaN  27.787872  ...
#
#           2013       2014       2015       2016       2017       2018  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1    27.580204  26.977380  24.805267  24.463397  24.531059  26.533601
# 2    20.444605  21.229663  22.124042  10.466808  10.051874  13.387247
# 3    28.253403  26.904888  22.611531  21.034257  24.128654  26.437118
# 4    53.362852  46.203326  41.933092  42.643568  42.167954  47.931542
# ..         ...        ...        ...        ...        ...        ...
# 261  27.187216  26.517067  26.943233  26.858427  27.527572  27.908359
# 262  43.880859  44.038109  36.367404  46.663196  42.218413  35.610679
# 263  24.551742  24.305282  23.732308  23.782537  23.610556  23.506994
# 264  32.556449  32.944148  33.657249  34.877167  37.304045  34.485322
# 265  23.799615  23.718548  22.358392  22.115059  21.404999  21.138422
#
#           2019       2020       2021  Unnamed: 66
# 0          NaN        NaN        NaN          NaN
# 1    26.403967  25.714514  25.840708          NaN
# 2    14.058112  14.031699        NaN          NaN
# 3    27.143541  27.358551  29.163412          NaN
# 4    49.760921  45.729022  43.385097          NaN
# ..         ...        ...        ...          ...
# 261  27.088384  27.558457  26.620263          NaN
# 262  35.610679  35.610679        NaN          NaN
# 263  23.577855  23.422275  24.463422          NaN
# 264  34.941981  40.257899  46.651853          NaN
# 265  34.691452  35.817145        NaN          NaN
#
# [266 rows x 67 columns]

# %%
df_industria = df_industria.drop(df_industria.loc[:,"Country Code":"2017"],axis=1).drop(df_industria.loc[:,"2021":],axis=1)
df_industria = df_industria.rename(columns={"Country Name":"Country","2020":"proporcion industris sobre PIB"})

# %%
#df_industria = pd.read_csv("Datos/industria.csv")
#df_industria = df_industria.drop(df_industria.loc[:,"Series Name":"Series Code"],axis=1).drop("Country Code",axis=1)
#df_industria = df_industria.rename(columns={"Country Name":"Country","2020 [YR2020]":"industria 2020 (cien millones)"})

# %%
df_industria = df_industria.fillna(method="ffill",axis=1)

# %%
df_industria = df_industria.drop(df_industria.loc[:,"2018":"2019"],axis=1)

# %%
df_industria["proporcion industris sobre PIB"]=pd.to_numeric(df_industria["proporcion industris sobre PIB"],'coerce')
df_industria=df_industria.dropna()

# %%
df_resultado = df_resultado.merge(df_industria,on="Country")
df_resultado
# Out:
#             Country  InternetPrice Country Code  population internet use 2020  \
# 0           Albania      21.160000          ALB                     72.240000
# 1           Algeria      45.180000          DZA                     62.900000
# 2         Argentina      29.414000          ARG                     85.500000
# 3           Armenia      17.690000          ARM                     76.510000
# 4         Australia      51.661250          AUS                     89.600000
# ..              ...            ...          ...                           ...
# 97   United Kingdom      37.690435          GBR                     94.818201
# 98    United States      66.410901          USA                     90.900000
# 99          Uruguay      32.340000          URY                     86.100000
# 100      Uzbekistan      33.560000          UZB                     71.100000
# 101        Zimbabwe     104.830000          ZWE                     29.300000
#
#      PIB 2020 (cien millones)  PIB_per_capita 2020  \
# 0                    0.148876          5246.292306
# 1                    1.450092          3306.858208
# 2                    3.892881          8579.017773
# 3                    0.126412          4266.018074
# 4                   13.278362         51692.842748
# ..                        ...                  ...
# 97                  27.598041         41059.168809
# 98                 209.530300         63593.443621
# 99                   0.536288         15438.411666
# 100                  0.599300          1750.697113
# 101                  0.180512          1214.509820
#
#      proporcion industris sobre PIB
# 0                         20.008609
# 1                         20.282297
# 2                         23.311218
# 3                         27.055226
# 4                         25.462096
# ..                              ...
# 97                        17.107108
# 98                        18.438755
# 99                        18.084251
# 100                       31.673638
# 101                       35.817145
#
# [102 rows x 7 columns]

# %%
df_resultado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 101
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         102 non-null    object
#  1   InternetPrice                   102 non-null    float64
#  2   Country Code                    102 non-null    object
#  3   population internet use 2020    102 non-null    float64
#  4   PIB 2020 (cien millones)        102 non-null    float64
#  5   PIB_per_capita 2020             102 non-null    float64
#  6   proporcion industris sobre PIB  102 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 6.4+ KB

# %%
df_resultado[df_resultado.isnull().T.any()]
df_resultado = df_resultado.dropna()

# %%
df_resultado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 102 entries, 0 to 101
# Data columns (total 7 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Country                         102 non-null    object
#  1   InternetPrice                   102 non-null    float64
#  2   Country Code                    102 non-null    object
#  3   population internet use 2020    102 non-null    float64
#  4   PIB 2020 (cien millones)        102 non-null    float64
#  5   PIB_per_capita 2020             102 non-null    float64
#  6   proporcion industris sobre PIB  102 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 6.4+ KB

# %%
df_clasificacion = pd.read_csv('Datos/clasificacion de paise.csv')
df_clasificacion
# Out:
#         Country Name Country Code  \
# 0              Aruba          ABW
# 1                NaN          AFE
# 2         Afganistán          AFG
# 3                NaN          AFW
# 4             Angola          AGO
# ..               ...          ...
# 261           Kosovo          XKX
# 262  Yemen, Rep. del          YEM
# 263        Sudáfrica          ZAF
# 264           Zambia          ZMB
# 265         Zimbabwe          ZWE
#
#                                                 Region  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                      Asia meridional
# 3                                                  NaN
# 4    África al sur del Sahara (excluido altos ingre...
# ..                                                 ...
# 261    Europa y Asia central (excluido altos ingresos)
# 262  Oriente Medio y Norte de África (excluido alto...
# 263  África al sur del Sahara (excluido altos ingre...
# 264  África al sur del Sahara (excluido altos ingre...
# 265  África al sur del Sahara (excluido altos ingre...
#
#                        Income_Group  Unnamed: 4
# 0                      Ingreso alto         NaN
# 1                         Agregados         NaN
# 2            Países de ingreso bajo         NaN
# 3                         Agregados         NaN
# 4    Países de ingreso mediano bajo         NaN
# ..                              ...         ...
# 261            Ingreso mediano alto         NaN
# 262          Países de ingreso bajo         NaN
# 263            Ingreso mediano alto         NaN
# 264          Países de ingreso bajo         NaN
# 265  Países de ingreso mediano bajo         NaN
#
# [266 rows x 5 columns]

# %%
df_clasificacion = df_clasificacion.drop("Region",axis=1).drop("Unnamed: 4",axis=1).drop("Country Name",axis=1)
df_clasificacion = df_clasificacion.rename(columns={"Country Name":"Country"})
df_clasificacion
# Out:
#     Country Code                    Income_Group
# 0            ABW                    Ingreso alto
# 1            AFE                       Agregados
# 2            AFG          Países de ingreso bajo
# 3            AFW                       Agregados
# 4            AGO  Países de ingreso mediano bajo
# ..           ...                             ...
# 261          XKX            Ingreso mediano alto
# 262          YEM          Países de ingreso bajo
# 263          ZAF            Ingreso mediano alto
# 264          ZMB          Países de ingreso bajo
# 265          ZWE  Países de ingreso mediano bajo
#
# [266 rows x 2 columns]

# %%
df_resultado = df_resultado.merge(df_clasificacion,on="Country Code")
df_resultado
# Out:
#             Country  InternetPrice Country Code  population internet use 2020  \
# 0           Albania      21.160000          ALB                     72.240000
# 1           Algeria      45.180000          DZA                     62.900000
# 2         Argentina      29.414000          ARG                     85.500000
# 3           Armenia      17.690000          ARM                     76.510000
# 4         Australia      51.661250          AUS                     89.600000
# ..              ...            ...          ...                           ...
# 97   United Kingdom      37.690435          GBR                     94.818201
# 98    United States      66.410901          USA                     90.900000
# 99          Uruguay      32.340000          URY                     86.100000
# 100      Uzbekistan      33.560000          UZB                     71.100000
# 101        Zimbabwe     104.830000          ZWE                     29.300000
#
#      PIB 2020 (cien millones)  PIB_per_capita 2020  \
# 0                    0.148876          5246.292306
# 1                    1.450092          3306.858208
# 2                    3.892881          8579.017773
# 3                    0.126412          4266.018074
# 4                   13.278362         51692.842748
# ..                        ...                  ...
# 97                  27.598041         41059.168809
# 98                 209.530300         63593.443621
# 99                   0.536288         15438.411666
# 100                  0.599300          1750.697113
# 101                  0.180512          1214.509820
#
#      proporcion industris sobre PIB                    Income_Group
# 0                         20.008609            Ingreso mediano alto
# 1                         20.282297  Países de ingreso mediano bajo
# 2                         23.311218            Ingreso mediano alto
# 3                         27.055226            Ingreso mediano alto
# 4                         25.462096                    Ingreso alto
# ..                              ...                             ...
# 97                        17.107108                    Ingreso alto
# 98                        18.438755                    Ingreso alto
# 99                        18.084251                    Ingreso alto
# 100                       31.673638  Países de ingreso mediano bajo
# 101                       35.817145  Países de ingreso mediano bajo
#
# [102 rows x 8 columns]

# %%
df_velocidad = pd.read_csv('Datos/internet broadband and mobile speeds by country.csv')
df_velocidad
# Out:
#              Country  Broadband Speed Rank  Broadband Mbps  Mobile Speed Rank  \
# 0             Monaco                   1.0          192.68                NaN
# 1          Singapore                   2.0          192.01               19.0
# 2              Chile                   3.0          189.36              109.0
# 3           Thailand                   4.0          184.03               56.0
# 4    Hong Kong (SAR)                   5.0          173.42               38.0
# ..               ...                   ...             ...                ...
# 174            Yemen                 175.0            2.74              140.0
# 175         Ethiopia                 176.0            2.69               78.0
# 176             Cuba                 177.0            1.90              119.0
# 177     Turkmenistan                 178.0            1.89              139.0
# 178      Afghanistan                 179.0            1.62              138.0
#
#      Mobile Mbps         As of
# 0            NaN  January 2022
# 1          64.92  January 2022
# 2          15.50  January 2022
# 3          32.38  January 2022
# 4          45.86  January 2022
# ..           ...           ...
# 174         0.53  January 2022
# 175        22.83  January 2022
# 176        12.71  January 2022
# 177         3.09  January 2022
# 178         5.10  January 2022
#
# [179 rows x 6 columns]

# %%
df_velocidad = df_velocidad.drop("As of",axis=1).drop("Mobile Mbps",axis=1).drop("Mobile Speed Rank",axis=1)

# %%
df_velocidad
# Out:
#              Country  Broadband Speed Rank  Broadband Mbps
# 0             Monaco                   1.0          192.68
# 1          Singapore                   2.0          192.01
# 2              Chile                   3.0          189.36
# 3           Thailand                   4.0          184.03
# 4    Hong Kong (SAR)                   5.0          173.42
# ..               ...                   ...             ...
# 174            Yemen                 175.0            2.74
# 175         Ethiopia                 176.0            2.69
# 176             Cuba                 177.0            1.90
# 177     Turkmenistan                 178.0            1.89
# 178      Afghanistan                 179.0            1.62
#
# [179 rows x 3 columns]

# %%
df_velocidad[df_velocidad["Country"].str.contains('Ice')].values
# Out:
# array([], shape=(0, 3), dtype=object)

# %%
df_resultado[df_resultado["Country"].str.contains('Sri Lanka')].values
# Out:
# array([['Sri Lanka', 17.42, 'LKA', 35.0, 0.80676681933978,
#         3680.67347661745, 26.1901816418313,
#         'Países de ingreso mediano bajo']], dtype=object)

# %%
df_velocidad["Country"] = df_velocidad["Country"].replace('Russia', 'Russian Federation')
df_velocidad["Country"] = df_velocidad["Country"].replace('Czechia', 'Czech Republic')
df_velocidad["Country"] = df_velocidad["Country"].replace('Kyrgyzstan', 'Kyrgyz Republic')
df_velocidad["Country"] = df_velocidad["Country"].replace('Egypt', 'Egypt, Arab Rep.')
df_velocidad["Country"] = df_velocidad["Country"].replace('Iran', 'Iran, Islamic Rep.')
df_velocidad["Country"] = df_velocidad["Country"].replace('The Bahamas', 'Bahamas, The')
df_velocidad["Country"] = df_velocidad["Country"].replace('Turkey', 'Turkiye')
df_velocidad["Country"] = df_velocidad["Country"].replace('The Bahamas', 'Bahamas, The')
df_velocidad["Country"] = df_velocidad["Country"].replace('Slovakia', 'Slovak Republic')
df_velocidad["Country"] = df_velocidad["Country"].replace('South Korea', 'Korea, Rep.')
df_velocidad["Country"] = df_velocidad["Country"].replace('Brunei', 'Brunei Darussalam')

# %%
df_resultado = df_resultado.merge(df_velocidad,on="Country")
df_resultado
# Out:
#             Country  InternetPrice Country Code  population internet use 2020  \
# 0           Albania      21.160000          ALB                     72.240000
# 1           Algeria      45.180000          DZA                     62.900000
# 2         Argentina      29.414000          ARG                     85.500000
# 3           Armenia      17.690000          ARM                     76.510000
# 4         Australia      51.661250          AUS                     89.600000
# ..              ...            ...          ...                           ...
# 96   United Kingdom      37.690435          GBR                     94.818201
# 97    United States      66.410901          USA                     90.900000
# 98          Uruguay      32.340000          URY                     86.100000
# 99       Uzbekistan      33.560000          UZB                     71.100000
# 100        Zimbabwe     104.830000          ZWE                     29.300000
#
#      PIB 2020 (cien millones)  PIB_per_capita 2020  \
# 0                    0.148876          5246.292306
# 1                    1.450092          3306.858208
# 2                    3.892881          8579.017773
# 3                    0.126412          4266.018074
# 4                   13.278362         51692.842748
# ..                        ...                  ...
# 96                  27.598041         41059.168809
# 97                 209.530300         63593.443621
# 98                   0.536288         15438.411666
# 99                   0.599300          1750.697113
# 100                  0.180512          1214.509820
#
#      proporcion industris sobre PIB                    Income_Group  \
# 0                         20.008609            Ingreso mediano alto
# 1                         20.282297  Países de ingreso mediano bajo
# 2                         23.311218            Ingreso mediano alto
# 3                         27.055226            Ingreso mediano alto
# 4                         25.462096                    Ingreso alto
# ..                              ...                             ...
# 96                        17.107108                    Ingreso alto
# 97                        18.438755                    Ingreso alto
# 98                        18.084251                    Ingreso alto
# 99                        31.673638  Países de ingreso mediano bajo
# 100                       35.817145  Países de ingreso mediano bajo
#
#      Broadband Speed Rank  Broadband Mbps
# 0                    91.0           33.50
# 1                   144.0            9.72
# 2                    82.0           38.47
# 3                    88.0           34.26
# 4                    61.0           50.89
# ..                    ...             ...
# 96                   52.0           61.69
# 97                    9.0          143.76
# 98                   36.0           85.61
# 99                   84.0           36.85
# 100                 167.0            5.21
#
# [101 rows x 10 columns]

# %%
df_resultado.isnull().sum()
# Out:
# Country                           0
# InternetPrice                     0
# Country Code                      0
# population internet use 2020      0
# PIB 2020 (cien millones)          0
# PIB_per_capita 2020               0
# proporcion industris sobre PIB    0
# Income_Group                      0
# Broadband Speed Rank              0
# Broadband Mbps                    0
# dtype: int64

# %%
df_resultado["Income_Group"].value_counts()
# Out:
# Ingreso alto                      45
# Ingreso mediano alto              30
# Países de ingreso mediano bajo    25
# Países de ingreso bajo             1
# Name: Income_Group, dtype: int64

# %%
df_resultado = df_resultado.round(2)

# %%
#df_resultado["industria 2020 (cien millones)"] = df_resultado["industria 2020 (cien millones)"].apply(lambda x : x/(10**12))

# %%
df_resultado
# Out:
#             Country  InternetPrice Country Code  population internet use 2020  \
# 0           Albania          21.16          ALB                         72.24
# 1           Algeria          45.18          DZA                         62.90
# 2         Argentina          29.41          ARG                         85.50
# 3           Armenia          17.69          ARM                         76.51
# 4         Australia          51.66          AUS                         89.60
# ..              ...            ...          ...                           ...
# 96   United Kingdom          37.69          GBR                         94.82
# 97    United States          66.41          USA                         90.90
# 98          Uruguay          32.34          URY                         86.10
# 99       Uzbekistan          33.56          UZB                         71.10
# 100        Zimbabwe         104.83          ZWE                         29.30
#
#      PIB 2020 (cien millones)  PIB_per_capita 2020  \
# 0                        0.15              5246.29
# 1                        1.45              3306.86
# 2                        3.89              8579.02
# 3                        0.13              4266.02
# 4                       13.28             51692.84
# ..                        ...                  ...
# 96                      27.60             41059.17
# 97                     209.53             63593.44
# 98                       0.54             15438.41
# 99                       0.60              1750.70
# 100                      0.18              1214.51
#
#      proporcion industris sobre PIB                    Income_Group  \
# 0                             20.01            Ingreso mediano alto
# 1                             20.28  Países de ingreso mediano bajo
# 2                             23.31            Ingreso mediano alto
# 3                             27.06            Ingreso mediano alto
# 4                             25.46                    Ingreso alto
# ..                              ...                             ...
# 96                            17.11                    Ingreso alto
# 97                            18.44                    Ingreso alto
# 98                            18.08                    Ingreso alto
# 99                            31.67  Países de ingreso mediano bajo
# 100                           35.82  Países de ingreso mediano bajo
#
#      Broadband Speed Rank  Broadband Mbps
# 0                    91.0           33.50
# 1                   144.0            9.72
# 2                    82.0           38.47
# 3                    88.0           34.26
# 4                    61.0           50.89
# ..                    ...             ...
# 96                   52.0           61.69
# 97                    9.0          143.76
# 98                   36.0           85.61
# 99                   84.0           36.85
# 100                 167.0            5.21
#
# [101 rows x 10 columns]

# %%
plt.figure(figsize=(10,5))
sns.distplot(df_resultado["InternetPrice"],
             kde=False,
             bins=100);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(df_resultado["InternetPrice"]);
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
f, (axi1,axi2) = plt.subplots(2, 1, figsize=(10,5), sharex=True);
sns.boxplot(df_resultado["InternetPrice"],ax=axi1);
sns.distplot(df_resultado["InternetPrice"],
             kde=False,
             bins=100,ax=axi2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='InternetPrice'>

# %%
p_0 = np.percentile(df_resultado["InternetPrice"], 0) #Q0 #Min
p_25 = np.percentile(df_resultado["InternetPrice"], 25) #Q1
p_50 = np.percentile(df_resultado["InternetPrice"], 50) #Q2 #Mediana 中位数
p_75 = np.percentile(df_resultado["InternetPrice"], 75) #Q3
p_100 = np.percentile(df_resultado["InternetPrice"], 100) #Q4 #Max los cualtiles.

print("Valor del percentil 0:", p_0)
print("Valor del percentil 25:", p_25)
print("Valor del percentil 50:", p_50)
print("Valor del percentil 75:", p_75)
print("Valor del percentil 100:", p_100)
print("Valor media:", round(df_resultado["InternetPrice"].mean(),2) )
# Out:
# Valor del percentil 0: 5.01
# Valor del percentil 25: 21.16
# Valor del percentil 50: 33.06
# Valor del percentil 75: 49.69
# Valor del percentil 100: 111.43
# Valor media: 38.59

# %%
fig = px.choropleth(df_resultado,
                    locations='Country',
                    locationmode='country names',
                    color="InternetPrice",  
                    hover_name='Country',                    
                    title = "InternetPrice",
                    color_continuous_scale='reds'
                   )

# Adjusting map, legend, title placement
fig.update_layout(
    autosize=False,
    width=1200,
    height=600,
    margin=dict(
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
    template='seaborn',
    paper_bgcolor="rgb(255, 255, 255)",
    legend=dict(
        orientation="v",
        yanchor="auto",
        y=1,
        xanchor="right",
        x=1
))
 
fig.show()

# %%
fig = px.choropleth(df_resultado, locations='Country', locationmode='country names',scope='world',color="InternetPrice",  color_continuous_scale='reds')
fig.update_layout(margin={'r':0,'t':0,'l':0,'b':0}, coloraxis_colorbar=dict(
    title = "InternetPrice",
    ticks = 'outside',
    tickvals = [5,10,30,50,70,100],
    dtick = 7
))
fig.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df_resultado['PIB 2020 (cien millones)'],
                y=df_resultado['InternetPrice'],
                hue = df_resultado['Income_Group'], # separarlo por la clasificasion del pais
               s=100)

plt.xlim(left=-0.5,right=10)
# Out:
# (-0.5, 10.0)

# %%
df_15_min = df_resultado.sort_values(by=["InternetPrice"],ascending=True).head(15)
df_15_min
# Out:
#                Country  InternetPrice Country Code  \
# 94             Ukraine           5.01          UKR
# 77  Russian Federation           6.81          RUS
# 76             Romania           8.83          ROU
# 38               India          10.50          IND
# 46          Kazakhstan          11.34          KAZ
# 16            Bulgaria          11.80          BGR
# 52           Lithuania          11.90          LTU
# 9              Belarus          12.04          BLR
# 73              Poland          13.58          POL
# 37             Hungary          14.44          HUN
# 70               China          14.91          CHN
# 31             Georgia          15.08          GEO
# 92             Tunisia          15.20          TUN
# 49     Kyrgyz Republic          16.79          KGZ
# 81     Slovak Republic          16.89          SVK
#
#     population internet use 2020  PIB 2020 (cien millones)  \
# 94                         75.04                      1.55
# 77                         84.99                     14.83
# 76                         78.46                      2.49
# 38                         43.00                     26.60
# 46                         85.94                      1.71
# 16                         70.16                      0.70
# 52                         83.06                      0.57
# 9                          85.09                      0.60
# 73                         83.18                      5.97
# 37                         84.77                      1.56
# 70                         70.40                    147.23
# 31                         72.53                      0.16
# 92                         71.90                      0.42
# 49                         51.00                      0.08
# 81                         89.92                      1.05
#
#     PIB_per_capita 2020  proporcion industris sobre PIB  \
# 94              3724.94                           20.80
# 77             10126.72                           29.83
# 76             12896.09                           26.89
# 38              1927.71                           24.53
# 46              9122.23                           33.10
# 16             10079.20                           21.92
# 52             20233.64                           24.98
# 9               6424.15                           30.83
# 73             15720.99                           27.68
# 37             15980.74                           24.63
# 70             10434.78                           37.84
# 31              4266.69                           21.18
# 92              3521.59                           21.64
# 49              1173.61                           29.20
# 81             19266.51                           27.36
#
#                       Income_Group  Broadband Speed Rank  Broadband Mbps
# 94  Países de ingreso mediano bajo                  57.0           52.50
# 77            Ingreso mediano alto                  50.0           63.76
# 76                    Ingreso alto                  11.0          127.07
# 38  Países de ingreso mediano bajo                  72.0           47.08
# 46            Ingreso mediano alto                  90.0           33.76
# 16            Ingreso mediano alto                  55.0           55.90
# 52                    Ingreso alto                  39.0           79.81
# 9             Ingreso mediano alto                  74.0           45.67
# 73                    Ingreso alto                  35.0           86.20
# 37                    Ingreso alto                  20.0          100.65
# 70            Ingreso mediano alto                   8.0          155.79
# 31            Ingreso mediano alto                 116.0           20.18
# 92  Países de ingreso mediano bajo                 158.0            7.64
# 49  Países de ingreso mediano bajo                  76.0           43.31
# 81                    Ingreso alto                  71.0           47.34

# %%
plt.figure(figsize=(10,8))
sns.barplot(y='Country',
            x='InternetPrice',
            data=df_15_min,
            hue='Income_Group',
            dodge=False,
           ci=None)
# Out:
# <AxesSubplot:xlabel='InternetPrice', ylabel='Country'>

# %%
df_15_max = df_resultado.sort_values(by=["InternetPrice"],ascending=False).head(15)
df_15_max
# Out:
#                   Country  InternetPrice Country Code  \
# 15      Brunei Darussalam         111.43          BRN
# 55               Maldives         109.22          MDV
# 100              Zimbabwe         104.83          ZWE
# 95   United Arab Emirates         100.36          ARE
# 75                  Qatar          84.92          QAT
# 66                   Oman          81.81          OMN
# 13               Botswana          73.69          BWA
# 89               Tanzania          72.67          TZA
# 36               Honduras          69.29          HND
# 93                 Uganda          69.06          UGA
# 35              Guatemala          67.03          GTM
# 97          United States          66.41          USA
# 62              Nicaragua          62.55          NIC
# 78           Saudi Arabia          61.12          SAU
# 7                 Bahrain          60.52          BHR
#
#      population internet use 2020  PIB 2020 (cien millones)  \
# 15                          95.00                      0.12
# 55                          62.93                      0.04
# 100                         29.30                      0.18
# 95                         100.00                      3.59
# 75                          99.65                      1.44
# 66                          95.23                      0.74
# 13                          64.00                      0.15
# 89                          22.00                      0.62
# 36                          42.05                      0.24
# 93                          19.90                      0.38
# 35                          49.97                      0.78
# 97                          90.90                    209.53
# 62                          45.20                      0.13
# 78                          97.86                      7.00
# 7                           99.67                      0.35
#
#      PIB_per_capita 2020  proporcion industris sobre PIB  \
# 15              27442.95                           59.13
# 55               6924.11                           11.83
# 100              1214.51                           35.82
# 95              36284.56                           40.87
# 75              50124.39                           52.33
# 66              14485.39                           47.48
# 13               6404.90                           27.77
# 89               1076.47                           28.67
# 36               2389.01                           25.95
# 93                822.03                           26.49
# 35               4603.34                           22.08
# 97              63593.44                           18.44
# 62               1905.26                           25.82
# 78              20110.32                           40.11
# 7               20409.95                           40.25
#
#                        Income_Group  Broadband Speed Rank  Broadband Mbps
# 15                     Ingreso alto                  87.0           35.26
# 55             Ingreso mediano alto                 137.0           10.97
# 100  Países de ingreso mediano bajo                 167.0            5.21
# 95                     Ingreso alto                  15.0          111.79
# 75                     Ingreso alto                  43.0           72.22
# 66                     Ingreso alto                  78.0           42.65
# 13             Ingreso mediano alto                 160.0            7.22
# 89   Países de ingreso mediano bajo                 148.0            9.45
# 36   Países de ingreso mediano bajo                 104.0           25.98
# 93           Países de ingreso bajo                 145.0            9.57
# 35             Ingreso mediano alto                 110.0           21.56
# 97                     Ingreso alto                   9.0          143.76
# 62   Países de ingreso mediano bajo                  99.0           29.04
# 78                     Ingreso alto                  41.0           79.32
# 7                      Ingreso alto                  70.0           47.38

# %%
plt.figure(figsize=(10,8))
sns.barplot(y='Country',
            x='InternetPrice',
            data=df_15_max,
            hue='Income_Group',
            dodge=False,
           ci=None)
# Out:
# <AxesSubplot:xlabel='InternetPrice', ylabel='Country'>

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df_resultado.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=75, l=25, n=10),
            square=True,
            linewidths=.1,
            annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(7,7))
sns.heatmap(df_resultado.corr(),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=75, l=25, n=10),
            square=True,
            linewidths=.1,
            annot=True)
# Out:
# <AxesSubplot:>

# %%
f, (axi1,axi2) = plt.subplots(2, 1, figsize=(10,5), sharex=True);
sns.boxplot(df_resultado["population internet use 2020"],ax=axi1);
sns.distplot(df_resultado["population internet use 2020"],
             kde=False,
             bins=100,ax=axi2)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='population internet use 2020'>

# %%
p_0 = np.percentile(df_resultado["population internet use 2020"], 0) #Q0 #Min
p_25 = np.percentile(df_resultado["population internet use 2020"], 25) #Q1
p_50 = np.percentile(df_resultado["population internet use 2020"], 50) #Q2 #Mediana 中位数
p_75 = np.percentile(df_resultado["population internet use 2020"], 75) #Q3
p_100 = np.percentile(df_resultado["population internet use 2020"], 100) #Q4 #Max los cualtiles.

print("Valor del percentil 0:", p_0)
print("Valor del percentil 25:", p_25)
print("Valor del percentil 50:", p_50)
print("Valor del percentil 75:", p_75)
print("Valor del percentil 100:", p_100)
print("Valor media:", round(df_resultado["InternetPrice"].mean(),2) )
# Out:
# Valor del percentil 0: 19.9
# Valor del percentil 25: 64.6
# Valor del percentil 50: 80.53
# Valor del percentil 75: 89.81
# Valor del percentil 100: 100.0
# Valor media: 38.59

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x=df_resultado['PIB 2020 (cien millones)'],
                y=df_resultado["population internet use 2020"],
                hue = df_resultado['Income_Group'], # separarlo por la clasificasion del pais
               s=100)

plt.xlim(left=-0.5,right=10)
# Out:
# (-0.5, 10.0)

# %%
fig = px.choropleth(df_resultado, locations='Country', locationmode='country names',scope='world',color="population internet use 2020",  color_continuous_scale='reds')
fig.update_layout(margin={'r':0,'t':0,'l':0,'b':0}, coloraxis_colorbar=dict(
    title = "population internet use 2020",
    ticks = 'outside',
    tickvals = [5,10,30,50,70,100],
    dtick = 7
))

# %%
df_15_min_poblacion = df_resultado.sort_values(by=["population internet use 2020"],ascending=True).head(15)
df_15_min_poblacion
# Out:
#          Country  InternetPrice Country Code  population internet use 2020  \
# 93        Uganda          69.06          UGA                         19.90
# 89      Tanzania          72.67          TZA                         22.00
# 8     Bangladesh          28.59          BGD                         24.80
# 67      Pakistan          23.10          PAK                         25.00
# 100     Zimbabwe         104.83          ZWE                         29.30
# 47         Kenya          59.88          KEN                         29.50
# 86     Sri Lanka          17.42          LKA                         35.00
# 63       Nigeria          40.95          NGA                         35.50
# 60         Nepal          17.35          NPL                         37.70
# 59       Namibia          48.16          NAM                         41.00
# 36      Honduras          69.29          HND                         42.05
# 38         India          10.50          IND                         43.00
# 62     Nicaragua          62.55          NIC                         45.20
# 72   Philippines          48.43          PHL                         49.80
# 35     Guatemala          67.03          GTM                         49.97
#
#      PIB 2020 (cien millones)  PIB_per_capita 2020  \
# 93                       0.38               822.03
# 89                       0.62              1076.47
# 8                        3.23              1961.61
# 67                       2.63              1188.86
# 100                      0.18              1214.51
# 47                       1.01              1878.58
# 86                       0.81              3680.67
# 63                       4.32              2097.09
# 60                       0.34              1155.14
# 59                       0.11              4179.28
# 36                       0.24              2389.01
# 38                      26.60              1927.71
# 62                       0.13              1905.26
# 72                       3.61              3298.83
# 35                       0.78              4603.34
#
#      proporcion industris sobre PIB                    Income_Group  \
# 93                            26.49          Países de ingreso bajo
# 89                            28.67  Países de ingreso mediano bajo
# 8                             32.91  Países de ingreso mediano bajo
# 67                            18.60  Países de ingreso mediano bajo
# 100                           35.82  Países de ingreso mediano bajo
# 47                            17.40  Países de ingreso mediano bajo
# 86                            26.19  Países de ingreso mediano bajo
# 63                            28.22  Países de ingreso mediano bajo
# 60                            12.05  Países de ingreso mediano bajo
# 59                            25.85            Ingreso mediano alto
# 36                            25.95  Países de ingreso mediano bajo
# 38                            24.53  Países de ingreso mediano bajo
# 62                            25.82  Países de ingreso mediano bajo
# 72                            28.40  Países de ingreso mediano bajo
# 35                            22.08            Ingreso mediano alto
#
#      Broadband Speed Rank  Broadband Mbps
# 93                  145.0            9.57
# 89                  148.0            9.45
# 8                    94.0           31.52
# 67                  151.0            9.12
# 100                 167.0            5.21
# 47                  153.0            8.91
# 86                  112.0           20.94
# 63                  142.0           10.06
# 60                   79.0           39.73
# 59                  156.0            8.29
# 36                  104.0           25.98
# 38                   72.0           47.08
# 62                   99.0           29.04
# 72                   67.0           49.52
# 35                  110.0           21.56

# %%
plt.figure(figsize=(10,8))
sns.barplot(y='Country',
            x="population internet use 2020",
            data=df_15_min_poblacion,
            hue='Income_Group',
            dodge=False,
           ci=None)
# Out:
# <AxesSubplot:xlabel='population internet use 2020', ylabel='Country'>

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(y=df_resultado["PIB_per_capita 2020"],
                x=df_resultado["population internet use 2020"],
                hue = df_resultado['Income_Group'], # separarlo por la clasificasion del pais
               s=100)

plt.xlim(left=15,right=100)
# Out:
# (15.0, 100.0)

# %%
sns.pairplot(df_resultado,
             kind="scatter",
             hue='Income_Group',
             diag_kind="hist")

# %%
plt.figure(figsize=(12,8))
sns.lmplot(x='population internet use 2020',
                y='Broadband Mbps',
                data=df_resultado,
                hue = df_resultado['Income_Group'], # separarlo por la clasificasion del pais
               scatter=True,
               a.any())
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/arraysetops.py:270: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/cs/rvd9j8s97j53_gds4qpwbnbr0000gn/T/ipykernel_1894/1615613803.py in <module>
#       4                 data=df_resultado,
#       5                 hue = df_resultado['Income_Group'], # separarlo por la clasificasion del pais
# ----> 6                scatter=True)
#       7
#       8
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/seaborn/regression.py in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     602     # Reduce the dataframe to only needed columns
#     603     need_cols = [x, y, hue, col, row, units, x_partial, y_partial]
# --> 604     cols = np.unique([a for a in need_cols if a is not None]).tolist()
#     605     data = data[cols]
#     606
#
# <__array_function__ internals> in unique(*args, **kwargs)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     270     ar = np.asanyarray(ar)
#     271     if axis is None:
# --> 272         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     273         return _unpack_tuple(ret)
#     274
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     331         aux = ar[perm]
#     332     else:
# --> 333         ar.sort()
#     334         aux = ar
#     335     mask = np.empty(aux.shape, dtype=np.bool_)
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1536     def __nonzero__(self):
#    1537         raise ValueError(
# -> 1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1540         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
